# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(10)
vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
# Momento de primeira ordem
np.mean(vals)
# Out:
# 0.0025510280009574692

# %%
# Momento de segunda ordem
np.var(vals)
# Out:
# 0.24485871454384336

# %%
# Momento de terceira ordem
import scipy.stats as sp
sp.skew(vals)
# Nesse caso indica que possui uma cauda mais acentuada a esquerda
# Out:
# -0.028247129262427135

# %%
# Momento de quarta ordem
sp.kurtosis(vals)
#
# Out:
# 0.00017539964479196257

# %%
np.random.seed(10)
vals = np.random.normal(10, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
sp.skew(vals)
# Out:
# -0.02824712926243256
