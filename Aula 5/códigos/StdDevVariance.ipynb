# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(100)
incomes = np.random.normal(100.0, 20.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std(), incomes.var()
# Out:
# (np.float64(20.125927092006116), np.float64(405.05294131274576))

# %%
incomes = np.random.normal(100.0, 10.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes = np.random.normal(100.0, 150.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std(), incomes.var()
# Out:
# (np.float64(149.57544422024222), np.float64(22372.813513682788))

# %%
incomes = np.random.normal(100.0, 2.0, 2000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std(), incomes.var()
# Out:
# (np.float64(2.015219538925182), np.float64(4.061109790065823))
